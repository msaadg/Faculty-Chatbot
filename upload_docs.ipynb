# %% [markdown]
# ### IMPORTS

# %%
import os
import argparse
import glob
import html
import io
import re
import time
from pypdf import PdfReader, PdfWriter
from azure.identity import AzureDeveloperCliCredential
from azure.core.credentials import AzureKeyCredential
from azure.storage.blob import BlobServiceClient
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents.indexes.models import *
from azure.search.documents import SearchClient
from azure.ai.formrecognizer import DocumentAnalysisClient

# %%
from config import *

# %%
search_creds = AzureKeyCredential(searchkey)
storage_creds = storagekey

# %%
MAX_SECTION_LENGTH = 1000
SENTENCE_SEARCH_LIMIT = 100
SECTION_OVERLAP = 100

# %% [markdown]
# ### FUNCTIONS

# %%
def blob_name_from_file_page(filename, page = 0):
    if os.path.splitext(filename)[1].lower() == ".pdf":
        return os.path.splitext(os.path.basename(filename))[0] + f"-{page}" + ".pdf"
    else:
        return os.path.basename(filename)

# %%
def upload_blobs(filename):
    blob_service = BlobServiceClient(account_url=f"https://{storageaccount}.blob.core.windows.net", credential=storage_creds)
    blob_container = blob_service.get_container_client(container)
    if not blob_container.exists():
        blob_container.create_container()

    # if file is PDF split into pages and upload each page as a separate blob
    if os.path.splitext(filename)[1].lower() == ".pdf":
        reader = PdfReader(filename)
        pages = reader.pages
        for i in range(len(pages)):
            blob_name = blob_name_from_file_page(filename, i)
            if verbose: print(f"\tUploading blob for page {i} -> {blob_name}")
            f = io.BytesIO()
            writer = PdfWriter()
            writer.add_page(pages[i])
            writer.write(f)
            f.seek(0)
            blob_container.upload_blob(blob_name, f, overwrite=True)
    else:
        blob_name = blob_name_from_file_page(filename)
        with open(filename,"rb") as data:
            blob_container.upload_blob(blob_name, data, overwrite=True)


def table_to_html(table):
    table_html = "<table>"
    rows = [sorted([cell for cell in table.cells if cell.row_index == i], key=lambda cell: cell.column_index) for i in range(table.row_count)]
    for row_cells in rows:
        table_html += "<tr>"
        for cell in row_cells:
            tag = "th" if (cell.kind == "columnHeader" or cell.kind == "rowHeader") else "td"
            cell_spans = ""
            if cell.column_span > 1: cell_spans += f" colSpan={cell.column_span}"
            if cell.row_span > 1: cell_spans += f" rowSpan={cell.row_span}"
            table_html += f"<{tag}{cell_spans}>{html.escape(cell.content)}</{tag}>"
        table_html +="</tr>"
    table_html += "</table>"
    return table_html

def get_document_text(filename):
    offset = 0
    page_map = []
    if localpdfparser:
        reader = PdfReader(filename)
        pages = reader.pages
        for page_num, p in enumerate(pages):
            page_text = p.extract_text()
            page_map.append((page_num, offset, page_text))
            offset += len(page_text)
    else:
        if verbose: print(f"Extracting text from '{filename}' using Azure Form Recognizer")
        form_recognizer_client = DocumentAnalysisClient(endpoint=f"https://{formrecognizerservice}.cognitiveservices.azure.com/", credential=formrecognizer_creds, headers={"x-ms-useragent": "azure-search-chat-demo/1.0.0"})
        with open(filename, "rb") as f:
            poller = form_recognizer_client.begin_analyze_document("prebuilt-layout", document = f)
        form_recognizer_results = poller.result()

        for page_num, page in enumerate(form_recognizer_results.pages):
            tables_on_page = [table for table in form_recognizer_results.tables if table.bounding_regions[0].page_number == page_num + 1]

            # mark all positions of the table spans in the page
            page_offset = page.spans[0].offset
            page_length = page.spans[0].length
            table_chars = [-1]*page_length
            for table_id, table in enumerate(tables_on_page):
                for span in table.spans:
                    # replace all table spans with "table_id" in table_chars array
                    for i in range(span.length):
                        idx = span.offset - page_offset + i
                        if idx >=0 and idx < page_length:
                            table_chars[idx] = table_id

            # build page text by replacing charcters in table spans with table html
            page_text = ""
            added_tables = set()
            for idx, table_id in enumerate(table_chars):
                if table_id == -1:
                    page_text += form_recognizer_results.content[page_offset + idx]
                elif not table_id in added_tables:
                    page_text += table_to_html(tables_on_page[table_id])
                    added_tables.add(table_id)

            page_text += " "
            page_map.append((page_num, offset, page_text))
            offset += len(page_text)

    return page_map

# %%
def split_text(page_map):
    SENTENCE_ENDINGS = [".", "!", "?"]
    WORDS_BREAKS = [",", ";", ":", " ", "(", ")", "[", "]", "{", "}", "\t", "\n"]
    if verbose: print(f"Splitting '{filename}' into sections")

    def find_page(offset):
        l = len(page_map)
        for i in range(l - 1):
            if offset >= page_map[i][1] and offset < page_map[i + 1][1]:
                return i
        return l - 1

    all_text = "".join(p[2] for p in page_map)
    length = len(all_text)
    start = 0
    end = length
    while start + SECTION_OVERLAP < length:
        last_word = -1
        end = start + MAX_SECTION_LENGTH

        if end > length:
            end = length
        else:
            # Try to find the end of the sentence
            while end < length and (end - start - MAX_SECTION_LENGTH) < SENTENCE_SEARCH_LIMIT and all_text[end] not in SENTENCE_ENDINGS:
                if all_text[end] in WORDS_BREAKS:
                    last_word = end
                end += 1
            if end < length and all_text[end] not in SENTENCE_ENDINGS and last_word > 0:
                end = last_word # Fall back to at least keeping a whole word
        if end < length:
            end += 1

        # Try to find the start of the sentence or at least a whole word boundary
        last_word = -1
        while start > 0 and start > end - MAX_SECTION_LENGTH - 2 * SENTENCE_SEARCH_LIMIT and all_text[start] not in SENTENCE_ENDINGS:
            if all_text[start] in WORDS_BREAKS:
                last_word = start
            start -= 1
        if all_text[start] not in SENTENCE_ENDINGS and last_word > 0:
            start = last_word
        if start > 0:
            start += 1

        section_text = all_text[start:end]
        yield (section_text, find_page(start))

        last_table_start = section_text.rfind("<table")
        if (last_table_start > 2 * SENTENCE_SEARCH_LIMIT and last_table_start > section_text.rfind("</table")):
            # If the section ends with an unclosed table, we need to start the next section with the table.
            # If table starts inside SENTENCE_SEARCH_LIMIT, we ignore it, as that will cause an infinite loop for tables longer than MAX_SECTION_LENGTH
            # If last table starts inside SECTION_OVERLAP, keep overlapping
            if verbose: print(f"Section ends with unclosed table, starting next section with the table at page {find_page(start)} offset {start} table start {last_table_start}")
            start = min(end - SECTION_OVERLAP, start + last_table_start)
        else:
            start = end - SECTION_OVERLAP
        
    if start + SECTION_OVERLAP < end:
        yield (all_text[start:end], find_page(start))

def create_sections(filename, page_map):
    for i, (section, pagenum) in enumerate(split_text(page_map)):
        yield {
            "id": re.sub("^[^0-9a-zA-Z]+", "", re.sub("[^0-9a-zA-Z_-]", "_", f"{filename}-{i}")),
            "content": section,
            "category": category,
            "sourcepage": blob_name_from_file_page(filename, pagenum),
            "sourcefile": filename
        }

def create_search_index():
    if verbose: print(f"Ensuring search index {index} exists")
    index_client = SearchIndexClient(endpoint=f"https://{searchservice}.search.windows.net/",
                                     credential=search_creds)
    if index not in index_client.list_index_names():
        search_index = SearchIndex(
            name=index,
            fields=[
                SimpleField(name="id", type="Edm.String", key=True),
                SearchableField(name="content", type="Edm.String", analyzer_name="en.microsoft"),
                SimpleField(name="category", type="Edm.String", filterable=True, facetable=True),
                SimpleField(name="sourcepage", type="Edm.String", filterable=True, facetable=True),
                SimpleField(name="sourcefile", type="Edm.String", filterable=True, facetable=True)
            ],
            semantic_settings=SemanticSettings(
                configurations=[SemanticConfiguration(
                    name='default',
                    prioritized_fields=PrioritizedFields(
                        title_field=None, prioritized_content_fields=[SemanticField(field_name='content')]))])
        )
        if verbose: print(f"Creating {index} search index")
        index_client.create_index(search_index)
    else:
        if verbose: print(f"Search index {index} already exists")

def index_sections(filename, sections):
    if verbose: print(f"Indexing sections from '{filename}' into search index '{index}'")
    search_client = SearchClient(endpoint=f"https://{searchservice}.search.windows.net/",
                                    index_name=index,
                                    credential=search_creds)
    i = 0
    batch = []
    for s in sections:
        batch.append(s)
        i += 1
        if i % 1000 == 0:
            results = search_client.upload_documents(documents=batch)
            succeeded = sum([1 for r in results if r.succeeded])
            if verbose: print(f"\tIndexed {len(results)} sections, {succeeded} succeeded")
            batch = []

    if len(batch) > 0:
        results = search_client.upload_documents(documents=batch)
        succeeded = sum([1 for r in results if r.succeeded])
        if verbose: print(f"\tIndexed {len(results)} sections, {succeeded} succeeded")

def remove_from_index(filename):
    if verbose: print(f"Removing sections from '{filename or '<all>'}' from search index '{index}'")
    search_client = SearchClient(endpoint=f"https://{searchservice}.search.windows.net/",
                                    index_name=index,
                                    credential=search_creds)
    while True:
        filter = None if filename == None else f"sourcefile eq '{os.path.basename(filename)}'"
        r = search_client.search("", filter=filter, top=1000, include_total_count=True)
        if r.get_count() == 0:
            break
        r = search_client.delete_documents(documents=[{ "id": d["id"] } for d in r])
        if verbose: print(f"\tRemoved {len(r)} sections from index")
        # It can take a few seconds for search results to reflect changes, so wait a bit
        time.sleep(2)

# %%
create_search_index()
# Out:
# Ensuring search index documents-index exists
# Search index documents-index already exists

# %%
FILE_PATH
# Out:
# '/Users/muhammadsaad/Downloads/AZURE-AI-SEARCH-main'

# %%
for filename in glob.glob(FILE_PATH + "/Faculty_Handbook_HU.pdf"):
    if verbose: print(f"Processing '{filename}'")
    upload_blobs(filename)
    page_map = get_document_text(filename)
    sections = create_sections(filename, page_map)
    index_sections(filename, sections)
# Out:
# Processing '/Users/muhammadsaad/Downloads/AZURE-AI-SEARCH-main/Faculty_Handbook_HU.pdf'
# 	Uploading blob for page 0 -> Faculty_Handbook_HU-0.pdf
# 	Uploading blob for page 1 -> Faculty_Handbook_HU-1.pdf
# 	Uploading blob for page 2 -> Faculty_Handbook_HU-2.pdf
# 	Uploading blob for page 3 -> Faculty_Handbook_HU-3.pdf
# 	Uploading blob for page 4 -> Faculty_Handbook_HU-4.pdf
# 	Uploading blob for page 5 -> Faculty_Handbook_HU-5.pdf
# 	Uploading blob for page 6 -> Faculty_Handbook_HU-6.pdf
# 	Uploading blob for page 7 -> Faculty_Handbook_HU-7.pdf
# 	Uploading blob for page 8 -> Faculty_Handbook_HU-8.pdf
# 	Uploading blob for page 9 -> Faculty_Handbook_HU-9.pdf
# 	Uploading blob for page 10 -> Faculty_Handbook_HU-10.pdf
# 	Uploading blob for page 11 -> Faculty_Handbook_HU-11.pdf
# 	Uploading blob for page 12 -> Faculty_Handbook_HU-12.pdf
# 	Uploading blob for page 13 -> Faculty_Handbook_HU-13.pdf
# 	Uploading blob for page 14 -> Faculty_Handbook_HU-14.pdf
# 	Uploading blob for page 15 -> Faculty_Handbook_HU-15.pdf
# 	Uploading blob for page 16 -> Faculty_Handbook_HU-16.pdf
# 	Uploading blob for page 17 -> Faculty_Handbook_HU-17.pdf
# 	Uploading blob for page 18 -> Faculty_Handbook_HU-18.pdf
# 	Uploading blob for page 19 -> Faculty_Handbook_HU-19.pdf
# 	Uploading blob for page 20 -> Faculty_Handbook_HU-20.pdf
# 	Uploading blob for page 21 -> Faculty_Handbook_HU-21.pdf
# 	Uploading blob for page 22 -> Faculty_Handbook_HU-22.pdf
# 	Uploading blob for page 23 -> Faculty_Handbook_HU-23.pdf
# 	Uploading blob for page 24 -> Faculty_Handbook_HU-24.pdf
# 	Uploading blob for page 25 -> Faculty_Handbook_HU-25.pdf
# 	Uploading blob for page 26 -> Faculty_Handbook_HU-26.pdf
# 	Uploading blob for page 27 -> Faculty_Handbook_HU-27.pdf
# 	Uploading blob for page 28 -> Faculty_Handbook_HU-28.pdf
# 	Uploading blob for page 29 -> Faculty_Handbook_HU-29.pdf
# 	Uploading blob for page 30 -> Faculty_Handbook_HU-30.pdf
# 	Uploading blob for page 31 -> Faculty_Handbook_HU-31.pdf
# 	Uploading blob for page 32 -> Faculty_Handbook_HU-32.pdf
# 	Uploading blob for page 33 -> Faculty_Handbook_HU-33.pdf
# 	Uploading blob for page 34 -> Faculty_Handbook_HU-34.pdf
# 	Uploading blob for page 35 -> Faculty_Handbook_HU-35.pdf
# 	Uploading blob for page 36 -> Faculty_Handbook_HU-36.pdf
# 	Uploading blob for page 37 -> Faculty_Handbook_HU-37.pdf
# 	Uploading blob for page 38 -> Faculty_Handbook_HU-38.pdf
# 	Uploading blob for page 39 -> Faculty_Handbook_HU-39.pdf
# 	Uploading blob for page 40 -> Faculty_Handbook_HU-40.pdf
# 	Uploading blob for page 41 -> Faculty_Handbook_HU-41.pdf
# 	Uploading blob for page 42 -> Faculty_Handbook_HU-42.pdf
# 	Uploading blob for page 43 -> Faculty_Handbook_HU-43.pdf
# 	Uploading blob for page 44 -> Faculty_Handbook_HU-44.pdf
# 	Uploading blob for page 45 -> Faculty_Handbook_HU-45.pdf
# 	Uploading blob for page 46 -> Faculty_Handbook_HU-46.pdf
# 	Uploading blob for page 47 -> Faculty_Handbook_HU-47.pdf
# 	Uploading blob for page 48 -> Faculty_Handbook_HU-48.pdf
# 	Uploading blob for page 49 -> Faculty_Handbook_HU-49.pdf
# 	Uploading blob for page 50 -> Faculty_Handbook_HU-50.pdf
# 	Uploading blob for page 51 -> Faculty_Handbook_HU-51.pdf
# 	Uploading blob for page 52 -> Faculty_Handbook_HU-52.pdf
# 	Uploading blob for page 53 -> Faculty_Handbook_HU-53.pdf
# 	Uploading blob for page 54 -> Faculty_Handbook_HU-54.pdf
# 	Uploading blob for page 55 -> Faculty_Handbook_HU-55.pdf
# 	Uploading blob for page 56 -> Faculty_Handbook_HU-56.pdf
# 	Uploading blob for page 57 -> Faculty_Handbook_HU-57.pdf
# 	Uploading blob for page 58 -> Faculty_Handbook_HU-58.pdf
# 	Uploading blob for page 59 -> Faculty_Handbook_HU-59.pdf
# 	Uploading blob for page 60 -> Faculty_Handbook_HU-60.pdf
# 	Uploading blob for page 61 -> Faculty_Handbook_HU-61.pdf
# 	Uploading blob for page 62 -> Faculty_Handbook_HU-62.pdf
# 	Uploading blob for page 63 -> Faculty_Handbook_HU-63.pdf
# 	Uploading blob for page 64 -> Faculty_Handbook_HU-64.pdf
# 	Uploading blob for page 65 -> Faculty_Handbook_HU-65.pdf
# 	Uploading blob for page 66 -> Faculty_Handbook_HU-66.pdf
# 	Uploading blob for page 67 -> Faculty_Handbook_HU-67.pdf
# 	Uploading blob for page 68 -> Faculty_Handbook_HU-68.pdf
# 	Uploading blob for page 69 -> Faculty_Handbook_HU-69.pdf
# 	Uploading blob for page 70 -> Faculty_Handbook_HU-70.pdf
# 	Uploading blob for page 71 -> Faculty_Handbook_HU-71.pdf
# 	Uploading blob for page 72 -> Faculty_Handbook_HU-72.pdf
# 	Uploading blob for page 73 -> Faculty_Handbook_HU-73.pdf
# 	Uploading blob for page 74 -> Faculty_Handbook_HU-74.pdf
# 	Uploading blob for page 75 -> Faculty_Handbook_HU-75.pdf
# 	Uploading blob for page 76 -> Faculty_Handbook_HU-76.pdf
# 	Uploading blob for page 77 -> Faculty_Handbook_HU-77.pdf
# 	Uploading blob for page 78 -> Faculty_Handbook_HU-78.pdf
# 	Uploading blob for page 79 -> Faculty_Handbook_HU-79.pdf
# 	Uploading blob for page 80 -> Faculty_Handbook_HU-80.pdf
# 	Uploading blob for page 81 -> Faculty_Handbook_HU-81.pdf
# 	Uploading blob for page 82 -> Faculty_Handbook_HU-82.pdf
# 	Uploading blob for page 83 -> Faculty_Handbook_HU-83.pdf
# 	Uploading blob for page 84 -> Faculty_Handbook_HU-84.pdf
# 	Uploading blob for page 85 -> Faculty_Handbook_HU-85.pdf
# 	Uploading blob for page 86 -> Faculty_Handbook_HU-86.pdf
# 	Uploading blob for page 87 -> Faculty_Handbook_HU-87.pdf
# 	Uploading blob for page 88 -> Faculty_Handbook_HU-88.pdf
# 	Uploading blob for page 89 -> Faculty_Handbook_HU-89.pdf
# 	Uploading blob for page 90 -> Faculty_Handbook_HU-90.pdf
# 	Uploading blob for page 91 -> Faculty_Handbook_HU-91.pdf
# 	Uploading blob for page 92 -> Faculty_Handbook_HU-92.pdf
# 	Uploading blob for page 93 -> Faculty_Handbook_HU-93.pdf
# 	Uploading blob for page 94 -> Faculty_Handbook_HU-94.pdf
# 	Uploading blob for page 95 -> Faculty_Handbook_HU-95.pdf
# 	Uploading blob for page 96 -> Faculty_Handbook_HU-96.pdf
# 	Uploading blob for page 97 -> Faculty_Handbook_HU-97.pdf
# 	Uploading blob for page 98 -> Faculty_Handbook_HU-98.pdf
# 	Uploading blob for page 99 -> Faculty_Handbook_HU-99.pdf
# 	Uploading blob for page 100 -> Faculty_Handbook_HU-100.pdf
# 	Uploading blob for page 101 -> Faculty_Handbook_HU-101.pdf
# 	Uploading blob for page 102 -> Faculty_Handbook_HU-102.pdf
# 	Uploading blob for page 103 -> Faculty_Handbook_HU-103.pdf
# 	Uploading blob for page 104 -> Faculty_Handbook_HU-104.pdf
# 	Uploading blob for page 105 -> Faculty_Handbook_HU-105.pdf
# 	Uploading blob for page 106 -> Faculty_Handbook_HU-106.pdf
# 	Uploading blob for page 107 -> Faculty_Handbook_HU-107.pdf
# 	Uploading blob for page 108 -> Faculty_Handbook_HU-108.pdf
# 	Uploading blob for page 109 -> Faculty_Handbook_HU-109.pdf
# 	Uploading blob for page 110 -> Faculty_Handbook_HU-110.pdf
# 	Uploading blob for page 111 -> Faculty_Handbook_HU-111.pdf
# 	Uploading blob for page 112 -> Faculty_Handbook_HU-112.pdf
# 	Uploading blob for page 113 -> Faculty_Handbook_HU-113.pdf
# 	Uploading blob for page 114 -> Faculty_Handbook_HU-114.pdf
# 	Uploading blob for page 115 -> Faculty_Handbook_HU-115.pdf
# 	Uploading blob for page 116 -> Faculty_Handbook_HU-116.pdf
# 	Uploading blob for page 117 -> Faculty_Handbook_HU-117.pdf
# 	Uploading blob for page 118 -> Faculty_Handbook_HU-118.pdf
# 	Uploading blob for page 119 -> Faculty_Handbook_HU-119.pdf
# 	Uploading blob for page 120 -> Faculty_Handbook_HU-120.pdf
# 	Uploading blob for page 121 -> Faculty_Handbook_HU-121.pdf
# 	Uploading blob for page 122 -> Faculty_Handbook_HU-122.pdf
# 	Uploading blob for page 123 -> Faculty_Handbook_HU-123.pdf
# 	Uploading blob for page 124 -> Faculty_Handbook_HU-124.pdf
# 	Uploading blob for page 125 -> Faculty_Handbook_HU-125.pdf
# 	Uploading blob for page 126 -> Faculty_Handbook_HU-126.pdf
# 	Uploading blob for page 127 -> Faculty_Handbook_HU-127.pdf
# 	Uploading blob for page 128 -> Faculty_Handbook_HU-128.pdf
# 	Uploading blob for page 129 -> Faculty_Handbook_HU-129.pdf
# 	Uploading blob for page 130 -> Faculty_Handbook_HU-130.pdf
# 	Uploading blob for page 131 -> Faculty_Handbook_HU-131.pdf
# 	Uploading blob for page 132 -> Faculty_Handbook_HU-132.pdf
# 	Uploading blob for page 133 -> Faculty_Handbook_HU-133.pdf
# 	Uploading blob for page 134 -> Faculty_Handbook_HU-134.pdf
# 	Uploading blob for page 135 -> Faculty_Handbook_HU-135.pdf
# 	Uploading blob for page 136 -> Faculty_Handbook_HU-136.pdf
# 	Uploading blob for page 137 -> Faculty_Handbook_HU-137.pdf
# 	Uploading blob for page 138 -> Faculty_Handbook_HU-138.pdf
# 	Uploading blob for page 139 -> Faculty_Handbook_HU-139.pdf
# Indexing sections from '/Users/muhammadsaad/Downloads/AZURE-AI-SEARCH-main/Faculty_Handbook_HU.pdf' into search index 'documents-index'
# Splitting '/Users/muhammadsaad/Downloads/AZURE-AI-SEARCH-main/Faculty_Handbook_HU.pdf' into sections
# 	Indexed 351 sections, 351 succeeded
